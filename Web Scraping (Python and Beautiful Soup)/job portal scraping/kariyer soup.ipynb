# %%
import requests
from bs4 import BeautifulSoup

url='https://www.kariyer.net/ozgecmis/ahmetcan81?fbclid=IwAR3vLsuVsGp3rYWfxjAzWPRTpAdwpwahFYCO7DlTyQP5Gs1aX3W7ZP-I_vc'

r=requests.get(url)
htmlContent=r.content

soup=BeautifulSoup(htmlContent,'html.parser')
ec=soup.find_all('div',class_='experience-info')

print(ec)
# Out:
# [<div class="experience-info">
# <div class="row">
# <div class="fields col-16 position"><span class="field-name">Pozisyon</span> <span class="field-content"><strong>Yönetici Asistanı</strong></span></div>
# </div>
# <div class="row">
# <div class="fields col-5"><span class="field-name">Firma Adı</span> <span class="field-content">krclab</span></div>
# <div class="fields col-5"><span class="field-name">Şehir</span> <span class="field-content">Ankara</span></div>
# </div>
# <div class="row">
# <div class="fields col-5">
# <span class="field-name">Başlangıç Tarihi</span> <span class="field-content date"><span>11.2019</span></span>
# </div>
# <div class="fields col-5 date">
# <span class="field-name">Bitiş Tarihi</span>
# <span class="field-content">
#                                                                             Hala çalışıyorum
#                                                                         </span>
# </div>
# <div class="fields col-5"><span class="field-name">Çalışma Şekli</span> <span class="field-content">Sürekli / Tam zamanlı</span></div>
# </div>
# </div>, <div class="experience-info">
# <div class="row">
# <div class="fields col-16 position"><span class="field-name">Pozisyon</span> <span class="field-content"><strong>Resim İş Öğretmeni</strong></span></div>
# </div>
# <div class="row">
# <div class="fields col-5"><span class="field-name">Firma Adı</span> <span class="field-content">Halk Eğitim Merkezi</span></div>
# <div class="fields col-5"><span class="field-name">Şehir</span> <span class="field-content">Düzce</span></div>
# </div>
# <div class="row">
# <div class="fields col-5">
# <span class="field-name">Başlangıç Tarihi</span> <span class="field-content date"><span>01.2019</span></span>
# </div>
# <div class="fields col-5 date">
# <span class="field-name">Bitiş Tarihi</span>
# <span class="field-content">
#                                                                             10.2019
#                                                                         </span>
# </div>
# <div class="fields col-5"><span class="field-name">Çalışma Şekli</span> <span class="field-content">Sürekli / Tam zamanlı</span></div>
# </div>
# </div>, <div class="experience-info">
# <div class="row">
# <div class="fields col-16 position"><span class="field-name">Pozisyon</span> <span class="field-content"><strong>Tasarım Elemanı</strong></span></div>
# </div>
# <div class="row">
# <div class="fields col-5"><span class="field-name">Firma Adı</span> <span class="field-content">Confetti Halı Sanayi A.Ş.</span></div>
# <div class="fields col-5"><span class="field-name">Şehir</span> <span class="field-content">Düzce</span></div>
# </div>
# <div class="row">
# <div class="fields col-5">
# <span class="field-name">Başlangıç Tarihi</span> <span class="field-content date"><span>02.2017</span></span>
# </div>
# <div class="fields col-5 date">
# <span class="field-name">Bitiş Tarihi</span>
# <span class="field-content">
#                                                                             12.2017
#                                                                         </span>
# </div>
# <div class="fields col-5"><span class="field-name">Çalışma Şekli</span> <span class="field-content">Sürekli / Tam zamanlı</span></div>
# </div>
# <div class="row">
# <div class="fields col-16"><span class="field-name">İş Tanımı</span> <span class="field-content rich-text">Desinatör ve üretim takibi</span></div>
# </div>
# </div>, <div class="experience-info">
# <div class="row">
# <div class="fields col-16 position"><span class="field-name">Pozisyon</span> <span class="field-content"><strong>Resim İş Öğretmeni</strong></span></div>
# </div>
# <div class="row">
# <div class="fields col-5"><span class="field-name">Firma Adı</span> <span class="field-content">Halk Eğitim Merkezi</span></div>
# <div class="fields col-5"><span class="field-name">Şehir</span> <span class="field-content">Düzce</span></div>
# </div>
# <div class="row">
# <div class="fields col-5">
# <span class="field-name">Başlangıç Tarihi</span> <span class="field-content date"><span>01.2016</span></span>
# </div>
# <div class="fields col-5 date">
# <span class="field-name">Bitiş Tarihi</span>
# <span class="field-content">
#                                                                             02.2017
#                                                                         </span>
# </div>
# <div class="fields col-5"><span class="field-name">Çalışma Şekli</span> <span class="field-content">Sürekli / Tam zamanlı</span></div>
# </div>
# <div class="row">
# <div class="fields col-16"><span class="field-name">İş Tanımı</span> <span class="field-content rich-text">Kalk eğitim kurumu aracılığı ile mahkumlara resim eğitimi verdim</span></div>
# </div>
# </div>, <div class="experience-info">
# <div class="row">
# <div class="fields col-16 position"><span class="field-name">Pozisyon</span> <span class="field-content"><strong>Grafik Tasarım Sorumlusu</strong></span></div>
# </div>
# <div class="row">
# <div class="fields col-5"><span class="field-name">Firma Adı</span> <span class="field-content">Sma Metrostar</span></div>
# <div class="fields col-5"><span class="field-name">Şehir</span> <span class="field-content">İstanbul(Asya)</span></div>
# </div>
# <div class="row">
# <div class="fields col-5">
# <span class="field-name">Başlangıç Tarihi</span> <span class="field-content date"><span>08.2015</span></span>
# </div>
# <div class="fields col-5 date">
# <span class="field-name">Bitiş Tarihi</span>
# <span class="field-content">
#                                                                             12.2015
#                                                                         </span>
# </div>
# <div class="fields col-5"><span class="field-name">Çalışma Şekli</span> <span class="field-content">Sürekli / Tam zamanlı</span></div>
# </div>
# </div>, <div class="experience-info">
# <div class="row">
# <div class="fields col-16 position"><span class="field-name">Pozisyon</span> <span class="field-content"><strong>Grafik Tasarım Sorumlusu</strong></span></div>
# </div>
# <div class="row">
# <div class="fields col-5"><span class="field-name">Firma Adı</span> <span class="field-content">şenil reklam</span></div>
# </div>
# <div class="row">
# <div class="fields col-5">
# <span class="field-name">Başlangıç Tarihi</span> <span class="field-content date"><span>09.2010</span></span>
# </div>
# <div class="fields col-5 date">
# <span class="field-name">Bitiş Tarihi</span>
# <span class="field-content">
#                                                                             09.2011
#                                                                         </span>
# </div>
# </div>
# </div>]

# %%
##full check ## work experience
import requests
from bs4 import BeautifulSoup

url='https://www.kariyer.net/ozgecmis/ahmetcan81?fbclid=IwAR3vLsuVsGp3rYWfxjAzWPRTpAdwpwahFYCO7DlTyQP5Gs1aX3W7ZP-I_vc'

r=requests.get(url)
htmlContent=r.content

soup=BeautifulSoup(htmlContent,'html.parser')

ec=soup.find_all('div',class_='resume-edit--job-experience-info')
list1=[]
works=[]
pos_loc=[]

for i in ec:
    work = []
    for span in i.find_all('span',{'class':['field-name','field-content']}):
        work.append(span.text.strip())
    works.append(work)
    pos_loc=[i for i, x in enumerate(works[0]) if x == "Pozisyon"]
    
    for i in range(len(pos_loc)-1):
        list1.append(works[0][pos_loc[i]:pos_loc[i+1]])
    
        
print(len(list1))
# print(works[0])

print(list1)
# Out:
# 5
# [['Pozisyon', 'Yönetici Asistanı', 'Firma Adı', 'krclab', 'Şehir', 'Ankara', 'Başlangıç Tarihi', '11.2019', 'Bitiş Tarihi', 'Hala çalışıyorum', 'Çalışma Şekli', 'Sürekli / Tam zamanlı'], ['Pozisyon', 'Resim İş Öğretmeni', 'Firma Adı', 'Halk Eğitim Merkezi', 'Şehir', 'Düzce', 'Başlangıç Tarihi', '01.2019', 'Bitiş Tarihi', '10.2019', 'Çalışma Şekli', 'Sürekli / Tam zamanlı'], ['Pozisyon', 'Tasarım Elemanı', 'Firma Adı', 'Confetti Halı Sanayi A.Ş.', 'Şehir', 'Düzce', 'Başlangıç Tarihi', '02.2017', 'Bitiş Tarihi', '12.2017', 'Çalışma Şekli', 'Sürekli / Tam zamanlı', 'İş Tanımı', 'Desinatör ve üretim takibi'], ['Pozisyon', 'Resim İş Öğretmeni', 'Firma Adı', 'Halk Eğitim Merkezi', 'Şehir', 'Düzce', 'Başlangıç Tarihi', '01.2016', 'Bitiş Tarihi', '02.2017', 'Çalışma Şekli', 'Sürekli / Tam zamanlı', 'İş Tanımı', 'Kalk eğitim kurumu aracılığı ile mahkumlara resim eğitimi verdim'], ['Pozisyon', 'Grafik Tasarım Sorumlusu', 'Firma Adı', 'Sma Metrostar', 'Şehir', 'İstanbul(Asya)', 'Başlangıç Tarihi', '08.2015', 'Bitiş Tarihi', '12.2015', 'Çalışma Şekli', 'Sürekli / Tam zamanlı']]

# %%
##full check ## work experience
import requests
from bs4 import BeautifulSoup

url='https://www.kariyer.net/ozgecmis/ahmetcan81?fbclid=IwAR3vLsuVsGp3rYWfxjAzWPRTpAdwpwahFYCO7DlTyQP5Gs1aX3W7ZP-I_vc'

r=requests.get(url)
htmlContent=r.content

soup=BeautifulSoup(htmlContent,'html.parser')

ec=soup.find_all('div',class_='resume-edit--job-experience-info')
items_list=[]
for i in ec:
    count = 0
    flag = False   
    items_list.clear()
    for span in i.find_all('span', {'class':['field-name','field-content','experience']}):
        tmp_text=span.text.strip()        
        items_list.append(tmp_text)
        #print(tmp_text)
print(items_list)
# Out:
# ['6 ay', 'Pozisyon', 'Yönetici Asistanı', 'Firma Adı', 'krclab', 'Şehir', 'Ankara', 'Başlangıç Tarihi', '11.2019', 'Bitiş Tarihi', 'Hala çalışıyorum', 'Çalışma Şekli', 'Sürekli / Tam zamanlı', '10 ay', 'Pozisyon', 'Resim İş Öğretmeni', 'Firma Adı', 'Halk Eğitim Merkezi', 'Şehir', 'Düzce', 'Başlangıç Tarihi', '01.2019', 'Bitiş Tarihi', '10.2019', 'Çalışma Şekli', 'Sürekli / Tam zamanlı', '11 ay', 'Pozisyon', 'Tasarım Elemanı', 'Firma Adı', 'Confetti Halı Sanayi A.Ş.', 'Şehir', 'Düzce', 'Başlangıç Tarihi', '02.2017', 'Bitiş Tarihi', '12.2017', 'Çalışma Şekli', 'Sürekli / Tam zamanlı', 'İş Tanımı', 'Desinatör ve üretim takibi', '1 yıl\n\n 2 ay', 'Pozisyon', 'Resim İş Öğretmeni', 'Firma Adı', 'Halk Eğitim Merkezi', 'Şehir', 'Düzce', 'Başlangıç Tarihi', '01.2016', 'Bitiş Tarihi', '02.2017', 'Çalışma Şekli', 'Sürekli / Tam zamanlı', 'İş Tanımı', 'Kalk eğitim kurumu aracılığı ile mahkumlara resim eğitimi verdim', '5 ay', 'Pozisyon', 'Grafik Tasarım Sorumlusu', 'Firma Adı', 'Sma Metrostar', 'Şehir', 'İstanbul(Asya)', 'Başlangıç Tarihi', '08.2015', 'Bitiş Tarihi', '12.2015', 'Çalışma Şekli', 'Sürekli / Tam zamanlı', '1 yıl\n\n 1 ay', 'Pozisyon', 'Grafik Tasarım Sorumlusu', 'Firma Adı', 'şenil reklam', 'Başlangıç Tarihi', '09.2010', 'Bitiş Tarihi', '09.2011']

# %%
list2=list()
count = 0
list1=[]
for item in items_list:
    if count == 0 and item == 'Pozisyon':
        list1.clear()
        list1.append(item)
        count+=1
    elif item != 'Pozisyon':
        list1.append(item)
        count+=1
    else:             
        #print(list1)
        tmp=list1.copy()
        list2.append(tmp)
        list1.clear()
        count = 0
        list1.append(item)        
print(list2)

print(len(list2))
# Out:
# [['6 ay'], ['Pozisyon', 'Yönetici Asistanı', 'Firma Adı', 'krclab', 'Şehir', 'Ankara', 'Başlangıç Tarihi', '11.2019', 'Bitiş Tarihi', 'Hala çalışıyorum', 'Çalışma Şekli', 'Sürekli / Tam zamanlı', '10 ay'], ['Pozisyon', 'Resim İş Öğretmeni', 'Firma Adı', 'Halk Eğitim Merkezi', 'Şehir', 'Düzce', 'Başlangıç Tarihi', '01.2019', 'Bitiş Tarihi', '10.2019', 'Çalışma Şekli', 'Sürekli / Tam zamanlı', '11 ay'], ['Pozisyon', 'Tasarım Elemanı', 'Firma Adı', 'Confetti Halı Sanayi A.Ş.', 'Şehir', 'Düzce', 'Başlangıç Tarihi', '02.2017', 'Bitiş Tarihi', '12.2017', 'Çalışma Şekli', 'Sürekli / Tam zamanlı', 'İş Tanımı', 'Desinatör ve üretim takibi', '1 yıl\n\n 2 ay'], ['Pozisyon', 'Resim İş Öğretmeni', 'Firma Adı', 'Halk Eğitim Merkezi', 'Şehir', 'Düzce', 'Başlangıç Tarihi', '01.2016', 'Bitiş Tarihi', '02.2017', 'Çalışma Şekli', 'Sürekli / Tam zamanlı', 'İş Tanımı', 'Kalk eğitim kurumu aracılığı ile mahkumlara resim eğitimi verdim', '5 ay'], ['Pozisyon', 'Grafik Tasarım Sorumlusu', 'Firma Adı', 'Sma Metrostar', 'Şehir', 'İstanbul(Asya)', 'Başlangıç Tarihi', '08.2015', 'Bitiş Tarihi', '12.2015', 'Çalışma Şekli', 'Sürekli / Tam zamanlı', '1 yıl\n\n 1 ay']]
# 6

# %%
items_list=[]

# %%
##full check ## work experience
import requests
from bs4 import BeautifulSoup

url='https://www.kariyer.net/ozgecmis/ahmetcan81?fbclid=IwAR3vLsuVsGp3rYWfxjAzWPRTpAdwpwahFYCO7DlTyQP5Gs1aX3W7ZP-I_vc'

r=requests.get(url)
htmlContent=r.content

soup=BeautifulSoup(htmlContent,'html.parser')

ec=soup.find_all('div',class_='resume-edit--job-experience-info')
for i in ec:
    count = 0
    flag = False   
    items_list.clear()
    for span in i.find_all('span', {'class':['experience']}):
        tmp_text=span.text.strip().replace('\n','')        
        items_list.append(tmp_text)
        #print(tmp_text)
print(items_list)
# Out:
# ['6 ay', '10 ay', '11 ay', '1 yıl 2 ay', '5 ay', '1 yıl 1 ay']

# %%
print(list2)
# Out:
# [['Pozisyon', 'Yönetici Asistanı', 'Firma Adı', 'krclab', 'Şehir', 'Ankara', 'Başlangıç Tarihi', '11.2019', 'Bitiş Tarihi', 'Hala çalışıyorum', 'Çalışma Şekli', 'Sürekli / Tam zamanlı'], ['Pozisyon', 'Resim İş Öğretmeni', 'Firma Adı', 'Halk Eğitim Merkezi', 'Şehir', 'Düzce', 'Başlangıç Tarihi', '01.2019', 'Bitiş Tarihi', '10.2019', 'Çalışma Şekli', 'Sürekli / Tam zamanlı'], ['Pozisyon', 'Tasarım Elemanı', 'Firma Adı', 'Confetti Halı Sanayi A.Ş.', 'Şehir', 'Düzce', 'Başlangıç Tarihi', '02.2017', 'Bitiş Tarihi', '12.2017', 'Çalışma Şekli', 'Sürekli / Tam zamanlı', 'İş Tanımı', 'Desinatör ve üretim takibi'], ['Pozisyon', 'Resim İş Öğretmeni', 'Firma Adı', 'Halk Eğitim Merkezi', 'Şehir', 'Düzce', 'Başlangıç Tarihi', '01.2016', 'Bitiş Tarihi', '02.2017', 'Çalışma Şekli', 'Sürekli / Tam zamanlı', 'İş Tanımı', 'Kalk eğitim kurumu aracılığı ile mahkumlara resim eğitimi verdim'], ['Pozisyon', 'Grafik Tasarım Sorumlusu', 'Firma Adı', 'Sma Metrostar', 'Şehir', 'İstanbul(Asya)', 'Başlangıç Tarihi', '08.2015', 'Bitiş Tarihi', '12.2015', 'Çalışma Şekli', 'Sürekli / Tam zamanlı']]

# %%
print(len(list2))
print(len(items_list))
# Out:
# 5
# 6

# %%
##full check ## education
import requests
from bs4 import BeautifulSoup

url='https://www.kariyer.net/ozgecmis/ahmetcan81?fbclid=IwAR3vLsuVsGp3rYWfxjAzWPRTpAdwpwahFYCO7DlTyQP5Gs1aX3W7ZP-I_vc'

r=requests.get(url)
htmlContent=r.content

soup=BeautifulSoup(htmlContent,'html.parser')

ec=soup.find_all('div',class_='resume-edit--education-info')

for i in ec:
    for span in i.find_all('span',{'class':['title','field-name','field-content']}):
        print(span.text)
# Out:
# Eğitim Bilgileri
# Lisans
# Üniversite
# Abant İzzet Baysal Üniversitesi
# Bölüm
# Resim-İş Öğretmenliği
# Başlangıç Tarihi
# 08.2010
# Bitiş Tarihi
#
# 08.2014
# Öğretim Tipi
# Örgün Öğretim
# Öğretim Dili
# Türkçe
# Yandal Bölüm
# Grafik Sanatları
# Lise
# Lise Adı
# Güzel Sanatlar lisesi
# Bölüm
# Resim
# Bitiş Tarihi
#
# 05.2010
# Öğretim Tipi
# Güzel Sanatlar Lisesi

# %%
##full check ## language
import requests
from bs4 import BeautifulSoup

url='https://www.kariyer.net/ozgecmis/ahmetcan81?fbclid=IwAR3vLsuVsGp3rYWfxjAzWPRTpAdwpwahFYCO7DlTyQP5Gs1aX3W7ZP-I_vc'

r=requests.get(url)
htmlContent=r.content

soup=BeautifulSoup(htmlContent,'html.parser')

ec=soup.find_all('div',class_='resume-edit--languages-info')

for i in ec:
    for span in i.find_all('span',{'class':['title','field-name','field-content']}):
        print(span.text)
# Out:
# Yabancı Dil
# Dil
# Seviye
#
# İngilizce
# Orta
#
# Orta

# %%
##full check ##Competencies
import requests
from bs4 import BeautifulSoup

url='https://www.kariyer.net/ozgecmis/ahmetcan81?fbclid=IwAR3vLsuVsGp3rYWfxjAzWPRTpAdwpwahFYCO7DlTyQP5Gs1aX3W7ZP-I_vc'

r=requests.get(url)
htmlContent=r.content

soup=BeautifulSoup(htmlContent,'html.parser')

ec=soup.find_all('div',class_='resume-edit--competences-info')

for i in ec:
    for span in i.find_all('span',{'class':['title','field-name','field-content']}):
        print(span.text)
# Out:
# Yetkinlikler
#
# Bilgisayar Bilgileri
#
# Microsoft Office adebe photoshop illüstratör indesgn freehan dreamwevaer flash php mysql java 3d studio max vray mantal ray vb. yazılımları iyi derce kullanmaktayım
# Sertifika Bilgileri
# Sertifika Adı
# TOPLUM LİDERLERİ GELİYOR
# Sertifika Tarihi
# 11.2012
# Alındığı Kurum
# ROTARY KULÜBÜ
# Açıklama
# KATILDIĞI SEMİNERLER VE ETKİNLİKLER :
# Stres ve zeka Yönetimi-
# Yeter ki inan-
# Liderlik-
# Görgü Görenek-
# Beden Dili-
# Motivasyon ve Özgüven-
# Güzel Giyinmenin Sırları-
# Takım Oyunları-
# Etkili İletişim-
# Kendi Everestinize Tırmanın-
# Cilt Bakımı ve Makyaz Eğitimi
# Sertifika Adı
# BİLGİSAYAR MESLEK DALI EĞİTİM PROGRAMLARI KURS SERTİFİKASI
# Sertifika Tarihi
# 07.2004
# Alındığı Kurum
# MED
# Açıklama
# Kurs içeriği:
# Windows
# Word
# Exel
# Power Point
# Acces
# İnternet Erişim
# Seminerler ve Kurslar
# Eğitim Adı
# MEB onaylı elginkan vakfı 3d studio max
# Eğitim Tarihi
#
#                                                                                 01.03.2012  01.04.2012
#
#
# Süre (Saat)
# 68 Saat
# Eğitim Kurumu
# Elignkan Vakfı
# Eğitim Adı
# Grafik Tasarım ve Animasyon Uygulamaları
# Eğitim Tarihi
#
#                                                                                 01.05.2011  01.06.2011
#
#
# Süre (Saat)
# 90 Saat
# Eğitim Kurumu
# Elginkan Vakfı
# Yetenekler
# JavaScript Object Notation (JSON)
# Resim
# Ressam
# Resim Yapmak
# Responsive Design
# Öğretmen
# jQuery
# HTML5
# jQuery
# Art Diractor
# CSS / HTML
# PHP (İyi)
# Html, Css, Php
# Apache PHP Mysql
# Adobe After Effects(İleri)
# Adobe Indesign (Üst Seviye)
# Adobe Flash (İyi Seviye)
# •	Adobe Dreamwear(İyi Derece)
# •	Adobe Illustrator(İyi Derece)
# •	Adobe Photoshop(İyi Derece)
# Mental Ray Renderer
# 3D Max
# 3D Design
# 3D Animation
# Profesyönel Fotoğrafçılık
# Grafık Tasarım
# Resim Öğretmeni
# Grafık Tasarım Resım
# Görsel Tasarım Ve  Sanatsal Çizim Resim

# %%
##full check ##grants
import requests
from bs4 import BeautifulSoup

url='https://www.kariyer.net/ozgecmis/ahmetcan81?fbclid=IwAR3vLsuVsGp3rYWfxjAzWPRTpAdwpwahFYCO7DlTyQP5Gs1aX3W7ZP-I_vc'

r=requests.get(url)
htmlContent=r.content

soup=BeautifulSoup(htmlContent,'html.parser')

ec=soup.find_all('div',class_='resume-edit--scholarships-info')

for i in ec:
    for span in i.find_all('span',{'class':['title','field-content']}):
        print(span.text)
# Out:
# Burslar
# Teşekkür Belgesi :
# 24.05.2014 tarihinde topluma hizmet uygulamaları kapsamında Abant İzzet Baysal Üniversitesi Diş Hekimliği Çocuk Diş Hekimliği (pedodonti) ana bilim dalı kliniğinde gerçekleştirilen duvar resim etkinliği
# Teşekkür Belgesi :
# 23.05.2014 tarihinde topluma hizmet uygulamaları kapsamında Abant İzzet Baysal Üniversitesi Tıp Fakültesi Çocuk Sağlığı ve Hastalıkları ana bilim dalı kliniğinde gerçekleştirilen duvar resim etkinliği
# Katılım Belgesi :
# 12-16 Mayıs 2014 tarihleri arasnda yapılan Kütahya Sanat Festivaline katılım ve katkılar
# Katılım Belgesi :
# Kentsel Tasarım ve kent Estetiği seminer katılık ve katkı
# Katılım Belgesi :
# Eğitimci Düşünce ve Gençlik Topluluğu 09-05-2011 "okul öncesi eğitiminden yüksek öğretime beyin dostu eğitim ortamları" konulu seminere katılım ve katkılar

# %%
##full check ## hobbies and interest
import requests
from bs4 import BeautifulSoup

url='https://www.kariyer.net/ozgecmis/ahmetcan81?fbclid=IwAR3vLsuVsGp3rYWfxjAzWPRTpAdwpwahFYCO7DlTyQP5Gs1aX3W7ZP-I_vc'

r=requests.get(url)
htmlContent=r.content

soup=BeautifulSoup(htmlContent,'html.parser')

ec=soup.find_all('div',class_='resume-edit--hobbies-and-interests-info')

for i in ec:
    for span in i.find_all('span',{'class':['title','field-content']}):
        print(span.text)
# Out:
# Hobiler ve İlgi Alanlarım
# Kitap okumak -
# Yeni bilimsel olayları takip etmek -
# Hayvanlar -
# Doğa yürüyüşü -
# Heykel

# %%
##Test Demo Test Demo 
import requests
from bs4 import BeautifulSoup

url='https://www.kariyer.net/ozgecmis/ahmetcan81?fbclid=IwAR3vLsuVsGp3rYWfxjAzWPRTpAdwpwahFYCO7DlTyQP5Gs1aX3W7ZP-I_vc'

r=requests.get(url)
htmlContent=r.content

soup=BeautifulSoup(htmlContent,'html.parser')

ec=soup.find_all('div',class_='contact-info')

for i in ec:
    for span in i.find_all('p',{'class':['candidate-name','candidate-job']}):
        print(span.text)
# Out:
# Ahmet Can
# Resim Öğretmeni-Grafik Tasarım

# %%
def get_personal_info(url):
    r=requests.get(url)
    htmlContent=r.content
    data=[]
    
    soup=BeautifulSoup(htmlContent,'html.parser')
    ec=soup.find_all('div',class_=['contact-info','resume-edit--summary-info'])
    for i in ec:
        for para in i.find_all('p',class_=['candidate-name','candidate-job']):
            data.append(para.text)
    for j in ec:
        for span in j.find_all('span',{'class':['title','field-content']}):
            data.append(span.text)
            
    return data
        
# persons=get_personal_info('https://www.kariyer.net/ozgecmis/ahmetcan81?fbclid=IwAR3vLsuVsGp3rYWfxjAzWPRTpAdwpwahFYCO7DlTyQP5Gs1aX3W7ZP-I_vc')    

# persons

# %%
import sys
import csv

# %%
FILE_NAME="persons.csv"

def write_person_info(id, person):    
    tmp_person = [id, person[0], person[1], person[2],person[3]]
    try:
        file = open(FILE_NAME, "a", encoding='utf-8')
        with file:
            writer = csv.writer(file)
            writer.writerow(tmp_person)
            print("Write on csv file")
        file.close()
    except:
        print("Error : "+sys.exc_info()[0])

# %%
persons=get_personal_info('https://www.kariyer.net/ozgecmis/ahmetcan81?fbclid=IwAR3vLsuVsGp3rYWfxjAzWPRTpAdwpwahFYCO7DlTyQP5Gs1aX3W7ZP-I_vc')    
write_person_info(1,persons)
# Out:
# Write on csv file

# %%
urls=[
    'https://www.kariyer.net/ozgecmis/ahmetcan81'
    'https://www.kariyer.net/ozgecmis/alpercapkin',
    'https://www.kariyer.net/ozgecmis/ahmetyolalaner',
    'https://www.kariyer.net/ozgecmis/ahmeddemirezen',
    'https://www.kariyer.net/ozgecmis/elifffatarrr',
    'https://www.kariyer.net/ozgecmis/elifgulsu',
    
]
persons=[]
for i in urls:
    persons.append(get_personal_info(i))
    
print(persons)
# Out:
# [[], ['Ahmet Yolalaner', '', 'Özet Bilgi', "AGÜ İnşaat Mühendisliği mezunuyum. Doğa sporlarına ve fotoğrafçılığa ilgiliyim. Erasmus+ kapsamında gençlik hareketliliklerini yakından takip ediyorum, 2 uluslararası, 2 ulusal gençlik projesine katıldım. Dil eğitimimi Northern Illinois University (Chicago, USA)'de ELS dil merkezinde tamamladım. AGÜ'de 2 öğrenci kulübünün kuruluşunda görev aldım."], ['Ahmed Demirezen', '', 'Özet Bilgi', 'Linklerhttps://github.com/ahmeddemirezenProjelerPython ile socket library kullanılarak geliştirdiğim raspberry pi ile iletişim programı. (https://github.com/ahmeddemirezen/Raspberry-Pi-Control-Server)EğitimAbdullah Gül Üniversitesi Endüstri Mühendisliği (2019-2024)H. Avni İncekara Fen Lisesi (2015-2019)'], ['Elif Atar', ''], ['Elif Gülsu', 'Satış ve Pazarlama Temsilcisi', 'Özet Bilgi', 'Merhaba Elif ben . ”Bu kadar senedir nasıl okulu bitiremedi” cümlesi aklınızdan geçiyor biliyorum onu belirtmek istiyorum : Maalesef hoca egosuna maruz kaldım. Bu beni yıkamadı tabi ki farklı birçok kurumsal firma da çalıştım , 6 senedir aktif özel ders öğretmenliği yapıyorum. ENERJİM VE HEYECANIM en büyük arkadaşım ;) İyi çalışmalar Sayın Yetkili ']]

# %%
id = 1
for person in person1:
    write_person_info(id, person)
    id+=1

# %%
def get_personal_details(url):
    personal_url = url
    response = requests.get(personal_url)
    html = response.content
    soup = BeautifulSoup(html, "html.parser")
    full_name = soup.find(class_="candidate-name")
    title = soup.find(class_="candidate-job")
    summary = soup.find(class_="resume-edit--summary-info")
    summary_body= summary.find(class_="content-body")
    #person =[full_name.text, title.text, summary_body.text.strip()]
    txt_fn='NA'
    txt_dg='NA'
    txt_su='NA'
    if full_name!=None:
        txt_fn=full_name.text
    if title!=None:
        txt_dg=title.text
    if summary_body!=None:
        txt_su=summary_body.text
        txt_su = txt_su.replace('\n','')
        print(txt_su)
    person=[txt_fn, txt_dg, txt_su]
    persons.append(person)

# %%
import requests

urls=[
    'https://www.kariyer.net/ozgecmis/ahmetcan81'
    'https://www.kariyer.net/ozgecmis/alpercapkin',
    'https://www.kariyer.net/ozgecmis/ahmetyolalaner',
    'https://www.kariyer.net/ozgecmis/ahmeddemirezen',
    'https://www.kariyer.net/ozgecmis/elifffatarrr',
    'https://www.kariyer.net/ozgecmis/elifgulsu',
    
]
persons=[]


def get_personal_info(url):
    r=requests.get(url)
    htmlContent=r.content
    data=[]
    datas=[]
    
    soup=BeautifulSoup(htmlContent,'html.parser')
    ec=soup.find_all('div',class_=['contact-info','resume-edit--summary-info'])
    for i in ec:
        for para in i.find_all('p',class_=['candidate-name','candidate-job']):
            data.append(para.text)
    for j in ec:
        for span in j.find_all('span',{'class':['title','field-content']}):
            data.append(span.text)
#             datas=[x for x in data if x]
            
    return data

trr=[]

for i in urls:
    persons.append(get_personal_info(i))
    trr=[x for x in persons if x]



FILE_NAME="persons.csv"

def write_person_info(id, person):    
    tmp_person = [id, person[0], person[1], person[2]]
    try:
        file = open(FILE_NAME, "a", encoding='utf-8')
        with file:
            writer = csv.writer(file)
            writer.writerow(tmp_person)
            print("Write on csv file")
        file.close()
    except:
        print("Error : "+sys.exc_info()[0])
        
# id = 1
# for person in person1:
#     write_person_info(id, person)
#     id+=1

id = 1
for person in trr:
    write_person_info(id, person)
    id+=1

# write_person_info(1,trr)
# Out:
# Write on csv file
# Write on csv file
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-5c789ed71d21> in <module>
#      60 id = 1
#      61 for person in trr:
# ---> 62     write_person_info(id, person)
#      63     id+=1
#      64
#
# <ipython-input-41-5c789ed71d21> in write_person_info(id, person)
#      42
#      43 def write_person_info(id, person):
# ---> 44     tmp_person = [id, person[0], person[1], person[2]]
#      45     try:
#      46         file = open(FILE_NAME, "a", encoding='utf-8')
#
# IndexError: list index out of range

# %%
print(trr)
# Out:
# [['Ahmet Yolalaner', '', 'Özet Bilgi', "AGÜ İnşaat Mühendisliği mezunuyum. Doğa sporlarına ve fotoğrafçılığa ilgiliyim. Erasmus+ kapsamında gençlik hareketliliklerini yakından takip ediyorum, 2 uluslararası, 2 ulusal gençlik projesine katıldım. Dil eğitimimi Northern Illinois University (Chicago, USA)'de ELS dil merkezinde tamamladım. AGÜ'de 2 öğrenci kulübünün kuruluşunda görev aldım."], ['Ahmed Demirezen', '', 'Özet Bilgi', 'Linklerhttps://github.com/ahmeddemirezenProjelerPython ile socket library kullanılarak geliştirdiğim raspberry pi ile iletişim programı. (https://github.com/ahmeddemirezen/Raspberry-Pi-Control-Server)EğitimAbdullah Gül Üniversitesi Endüstri Mühendisliği (2019-2024)H. Avni İncekara Fen Lisesi (2015-2019)'], ['Elif Atar', ''], ['Elif Gülsu', 'Satış ve Pazarlama Temsilcisi', 'Özet Bilgi', 'Merhaba Elif ben . ”Bu kadar senedir nasıl okulu bitiremedi” cümlesi aklınızdan geçiyor biliyorum onu belirtmek istiyorum : Maalesef hoca egosuna maruz kaldım. Bu beni yıkamadı tabi ki farklı birçok kurumsal firma da çalıştım , 6 senedir aktif özel ders öğretmenliği yapıyorum. ENERJİM VE HEYECANIM en büyük arkadaşım ;) İyi çalışmalar Sayın Yetkili ']]

# %% [markdown]
# ### Work Experinces

# %%
import bs4
import requests
import re
from bs4 import BeautifulSoup
personal_url = 'https://www.kariyer.net/ozgecmis/ahmetcan81'
counter=1
response = requests.get(personal_url)
html = response.content
soup = BeautifulSoup(html, "html.parser")
work_experinces = soup.find('div', class_="resume-edit--job-experience-info")
jobs = work_experinces.find_all('div', class_="resume-edit--job-experience")
print("Work Experinces")
for job in jobs:
    # Duration
    result31 = job.find('div', class_='experience-logo')
    result31_1 = result31.find('span', class_='experience')
    job_duration = result31_1.text.replace('\n', '')
    print(f'work_id : {counter}')
    print("Duration : ",job_duration.strip())

    result33 = job.find('div', class_='experience-info')
    result33_1 = result33.find_all('div', class_='row')
    result33_1 = result33.find_all('div', class_ = re.compile('^fields col-.*'))
    i = 0
    
    while(i<len(result33_1)):
        value1 = result33_1[i].find('span', class_="field-name")
        value2 = result33_1[i].find('span', class_ = re.compile('^field-content.*'))
        if value1!=None and value2!=None:
            
            print(value1.text.strip(), " : ",value2.text.strip())
        
        i+=1
    counter+=1
    print("-------------------------------------------------------------")
# Out:
# Work Experinces
# work_id : 1
# Duration :  6 ay
# Pozisyon  :  Yönetici Asistanı
# Firma Adı  :  krclab
# Şehir  :  Ankara
# Başlangıç Tarihi  :  11.2019
# Bitiş Tarihi  :  Hala çalışıyorum
# Çalışma Şekli  :  Sürekli / Tam zamanlı
# -------------------------------------------------------------
# work_id : 2
# Duration :  10 ay
# Pozisyon  :  Resim İş Öğretmeni
# Firma Adı  :  Halk Eğitim Merkezi
# Şehir  :  Düzce
# Başlangıç Tarihi  :  01.2019
# Bitiş Tarihi  :  10.2019
# Çalışma Şekli  :  Sürekli / Tam zamanlı
# -------------------------------------------------------------
# work_id : 3
# Duration :  11 ay
# Pozisyon  :  Tasarım Elemanı
# Firma Adı  :  Confetti Halı Sanayi A.Ş.
# Şehir  :  Düzce
# Başlangıç Tarihi  :  02.2017
# Bitiş Tarihi  :  12.2017
# Çalışma Şekli  :  Sürekli / Tam zamanlı
# İş Tanımı  :  Desinatör ve üretim takibi
# -------------------------------------------------------------
# work_id : 4
# Duration :  1 yıl 2 ay
# Pozisyon  :  Resim İş Öğretmeni
# Firma Adı  :  Halk Eğitim Merkezi
# Şehir  :  Düzce
# Başlangıç Tarihi  :  01.2016
# Bitiş Tarihi  :  02.2017
# Çalışma Şekli  :  Sürekli / Tam zamanlı
# İş Tanımı  :  Kalk eğitim kurumu aracılığı ile mahkumlara resim eğitimi verdim
# -------------------------------------------------------------
# work_id : 5
# Duration :  5 ay
# Pozisyon  :  Grafik Tasarım Sorumlusu
# Firma Adı  :  Sma Metrostar
# Şehir  :  İstanbul(Asya)
# Başlangıç Tarihi  :  08.2015
# Bitiş Tarihi  :  12.2015
# Çalışma Şekli  :  Sürekli / Tam zamanlı
# -------------------------------------------------------------
# work_id : 6
# Duration :  1 yıl 1 ay
# Pozisyon  :  Grafik Tasarım Sorumlusu
# Firma Adı  :  şenil reklam
# Başlangıç Tarihi  :  09.2010
# Bitiş Tarihi  :  09.2011
# -------------------------------------------------------------

# %% [markdown]
# #### Day 3 try

# %%
def get_work_experinces(person_id, url): 
    personal_url = url
    response = requests.get(personal_url)
    html = response.content
    soup = BeautifulSoup(html, "html.parser")
    work_experinces = soup.find('div', class_="resume-edit--job-experience-info")
    jobs = work_experinces.find_all('div', class_="resume-edit--job-experience")
    print("Work Experinces")
    id = 1
    experinces=[]    
    for job in jobs:
        experince=[]
         # Duration
        result31 = job.find('div', class_='experience-logo')
        result31_1 = result31.find('span', class_='experience')
        job_duration = result31_1.text.replace('\n', '')
        #print("ID : ",id)
        #print("Duration : ",job_duration.strip())        
        experince.append(person_id)
        experince.append(id)
        experince.append(job_duration.strip())
        
        result33 = job.find('div', class_='experience-info')
        result33_1 = result33.find_all('div', class_='row')
        result33_1 = result33.find_all('div', class_ = re.compile('^fields col-.*'))
        i = 0
        while(i<len(result33_1)):
            value1 = result33_1[i].find('span', class_="field-name")
            value2 = result33_1[i].find('span', class_ = re.compile('^field-content.*'))
            if value1!=None and value2!=None:
                #print(value1.text.strip(), " : ", value2.text.strip())
                experince.append(value2.text.strip())
            i+=1
        id+=1
        experinces.append(experince.copy())
        #print("-------------------------------------------------------------")
    return(experinces)
url="https://www.kariyer.net/ozgecmis/ahmetcan81"
a=get_work_experinces(1,url)
print(a)
# Out:
# Work Experinces
# [[1, 1, '6 ay', 'Yönetici Asistanı', 'krclab', 'Ankara', '11.2019', 'Hala çalışıyorum', 'Sürekli / Tam zamanlı'], [1, 2, '10 ay', 'Resim İş Öğretmeni', 'Halk Eğitim Merkezi', 'Düzce', '01.2019', '10.2019', 'Sürekli / Tam zamanlı'], [1, 3, '11 ay', 'Tasarım Elemanı', 'Confetti Halı Sanayi A.Ş.', 'Düzce', '02.2017', '12.2017', 'Sürekli / Tam zamanlı', 'Desinatör ve üretim takibi'], [1, 4, '1 yıl 2 ay', 'Resim İş Öğretmeni', 'Halk Eğitim Merkezi', 'Düzce', '01.2016', '02.2017', 'Sürekli / Tam zamanlı', 'Kalk eğitim kurumu aracılığı ile mahkumlara resim eğitimi verdim'], [1, 5, '5 ay', 'Grafik Tasarım Sorumlusu', 'Sma Metrostar', 'İstanbul(Asya)', '08.2015', '12.2015', 'Sürekli / Tam zamanlı'], [1, 6, '1 yıl 1 ay', 'Grafik Tasarım Sorumlusu', 'şenil reklam', '09.2010', '09.2011']]

# %%
def get_work_experinces(person_id, url): 
    personal_url = url
    response = requests.get(personal_url)
    html = response.content
    soup = BeautifulSoup(html, "html.parser")
    work_experinces = soup.find('div', class_="resume-edit--education-info")
    jobs = work_experinces.find_all('div', class_="university")
    print("Work Experinces")
    id = 1
    experinces=[]    
    for job in jobs:
        experince=[]
         # Duration
        result31 = job.find('div', class_='row logo')
        result31_1 = result31.find('span', class_='education-status')
        job_duration = result31_1.text.replace('\n', '')
        #print("ID : ",id)
        #print("Duration : ",job_duration.strip())        
        experince.append(person_id)
        experince.append(id)
        experince.append(job_duration.strip())
        
        result33 = job.find('div', class_='university-info')
        result33_1 = result33.find_all('div', class_='row')
        result33_1 = result33.find_all('div', class_ = re.compile('^fields col-.*'))
        i = 0
        while(i<len(result33_1)):
            value1 = result33_1[i].find('span', class_="field-name")
            value2 = result33_1[i].find('span', class_ = re.compile('^field-content.*'))
            if value1!=None and value2!=None:
                #print(value1.text.strip(), " : ", value2.text.strip())
                experince.append(value2.text.strip())
            i+=1
        id+=1
        experinces.append(experince.copy())
        #print("-------------------------------------------------------------")
    return(experinces)

url="https://www.kariyer.net/ozgecmis/ahmetcan81"
a=get_work_experinces(1,url)
print(a)
# Out:
# Work Experinces
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-d82911d9a1a7> in <module>
#      38
#      39 url="https://www.kariyer.net/ozgecmis/ahmetcan81"
# ---> 40 a=get_work_experinces(1,url)
#      41 print(a)
#
# <ipython-input-139-d82911d9a1a7> in get_work_experinces(person_id, url)
#      14         result31 = job.find('div', class_='row logo')
#      15         result31_1 = result31.find('span', class_='education-status')
# ---> 16         job_duration = result31_1.text.replace('\n', '')
#      17         #print("ID : ",id)
#      18         #print("Duration : ",job_duration.strip())
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
## education info 

import bs4
import requests
import re
from bs4 import BeautifulSoup
personal_url = 'https://www.kariyer.net/ozgecmis/ahmetcan81'
def get_education_details(person_id,personal_url):
    response = requests.get(personal_url)
    html = response.content
    soup = BeautifulSoup(html, "html.parser")
    sobject_1 = soup.find('div', class_="resume-edit--education-info")
    sobject_2 = sobject_1.find('div', class_="resume-edit--box")
    sobject_3 = sobject_2.find('div', class_="container")
    sobject_4 = sobject_3.find_all('div', class_="university")
    #print(len(sobject_4))
    edu=[]
    temp=[]
    educations=[]
    for tmp_obj1 in sobject_4: 
        #result5 = tmp_obj1.find('div', class_='fields col-16 education-status')    
        #result6 = result5.find('span', class_='field-content')    
        #university_name = result6.text
        #print(university_name)
        result7 = tmp_obj1.find('div', class_='fields col-13')
        result8 = tmp_obj1.find('div', class_='row university-info')

        for span in result8.find_all('span',class_=['field-name','field-content']):
            edu.append(span.text)

        temp=edu.copy()
        edu.clear()
        educations.append(temp)
    return educations

# %%
personal_url='https://www.kariyer.net/ozgecmis/elifgulsu'
get_education_details(1,personal_url)
# Out:
# [['Üniversite',
#   'Bülent Ecevit Üniversitesi',
#   'Bölüm',
#   'Matematik',
#   'Başlangıç Tarihi',
#   '09.2009',
#   'Bitiş Tarihi',
#   '\r\n...                                                                            '],
#  ['Lise Adı',
#   'halide edip adıvar anadolu lisesi',
#   'Bölüm',
#   'Matematik',
#   'Bitiş Tarihi',
#   '\r\n06.2009                                                                            ',
#   'Öğretim Tipi',
#   'Anadolu Lisesi']]

# %%
##full check ##Competencies
import requests
from bs4 import BeautifulSoup

url='https://www.kariyer.net/ozgecmis/ahmetcan81?fbclid=IwAR3vLsuVsGp3rYWfxjAzWPRTpAdwpwahFYCO7DlTyQP5Gs1aX3W7ZP-I_vc'

r=requests.get(url)
htmlContent=r.content

soup=BeautifulSoup(htmlContent,'html.parser')

ec=soup.find_all('div',class_='resume-edit--competences-info')

for i in ec:
    for span in i.find_all('span',{'class':['title','field-name','field-content']}):
        print(span.text)
# Out:
# Yetkinlikler
#
# Bilgisayar Bilgileri
#
# Microsoft Office adebe photoshop illüstratör indesgn freehan dreamwevaer flash php mysql java 3d studio max vray mantal ray vb. yazılımları iyi derce kullanmaktayım
# Sertifika Bilgileri
# Sertifika Adı
# TOPLUM LİDERLERİ GELİYOR
# Sertifika Tarihi
# 11.2012
# Alındığı Kurum
# ROTARY KULÜBÜ
# Açıklama
# KATILDIĞI SEMİNERLER VE ETKİNLİKLER :
# Stres ve zeka Yönetimi-
# Yeter ki inan-
# Liderlik-
# Görgü Görenek-
# Beden Dili-
# Motivasyon ve Özgüven-
# Güzel Giyinmenin Sırları-
# Takım Oyunları-
# Etkili İletişim-
# Kendi Everestinize Tırmanın-
# Cilt Bakımı ve Makyaz Eğitimi
# Sertifika Adı
# BİLGİSAYAR MESLEK DALI EĞİTİM PROGRAMLARI KURS SERTİFİKASI
# Sertifika Tarihi
# 07.2004
# Alındığı Kurum
# MED
# Açıklama
# Kurs içeriği:
# Windows
# Word
# Exel
# Power Point
# Acces
# İnternet Erişim
# Seminerler ve Kurslar
# Eğitim Adı
# MEB onaylı elginkan vakfı 3d studio max
# Eğitim Tarihi
#
#                                                                                 01.03.2012  01.04.2012
#
#
# Süre (Saat)
# 68 Saat
# Eğitim Kurumu
# Elignkan Vakfı
# Eğitim Adı
# Grafik Tasarım ve Animasyon Uygulamaları
# Eğitim Tarihi
#
#                                                                                 01.05.2011  01.06.2011
#
#
# Süre (Saat)
# 90 Saat
# Eğitim Kurumu
# Elginkan Vakfı
# Yetenekler
# JavaScript Object Notation (JSON)
# Resim
# Ressam
# Resim Yapmak
# Responsive Design
# Öğretmen
# jQuery
# HTML5
# jQuery
# Art Diractor
# CSS / HTML
# PHP (İyi)
# Html, Css, Php
# Apache PHP Mysql
# Adobe After Effects(İleri)
# Adobe Indesign (Üst Seviye)
# Adobe Flash (İyi Seviye)
# •	Adobe Dreamwear(İyi Derece)
# •	Adobe Illustrator(İyi Derece)
# •	Adobe Photoshop(İyi Derece)
# Mental Ray Renderer
# 3D Max
# 3D Design
# 3D Animation
# Profesyönel Fotoğrafçılık
# Grafık Tasarım
# Resim Öğretmeni
# Grafık Tasarım Resım
# Görsel Tasarım Ve  Sanatsal Çizim Resim

# %%
import bs4
import requests
import re
from bs4 import BeautifulSoup

def get_competences_info(id,url):
    response = requests.get(url)
    html = response.content
    soup = BeautifulSoup(html, "html.parser")
    comp=[]
    temp=[]
    index=[0,1,6,11]
    mix_comp=[]
    competences=[]
    sobject_1 = soup.find('div', class_="resume-edit--competences-info")
    sobject_2 = sobject_1.find('div', class_="resume-edit--box")
    sobject_3 = sobject_2.find('div', class_="container")
    sobject_4 = sobject_3.find_all('div', class_="row")
    
    for tmp_obj1 in sobject_4: 
        for span in tmp_obj1.find_all('span',class_=['field-name','field-content']):
            comp.append(span.text)
        temp=comp.copy()
        comp.clear()
        mix_comp.append(temp)
    for i in index:
        competences.append(mix_comp[i])

    return mix_comp

# %%
url='https://www.kariyer.net/ozgecmis/ahmetcan81'
get_competences_info(1,url)
# Out:
# [['\xa0',
#   'Bilgisayar Bilgileri',
#   '\xa0',
#   'Microsoft Office adebe photoshop illüstratör indesgn freehan dreamwevaer flash php mysql java 3d studio max vray mantal ray vb. yazılımları iyi derce kullanmaktayım'],
#  ['Sertifika Bilgileri',
#   'Sertifika Adı',
#   'TOPLUM LİDERLERİ GELİYOR',
#   'Sertifika Tarihi',
#   '11.2012',
#   'Alındığı Kurum',
#   'ROTARY KULÜBÜ',
#   'Açıklama',
#   'KATILDIĞI SEMİNERLER VE ETKİNLİKLER : \r\nStres ve zeka Yönetimi-\r\nYeter ki inan-\r\nLiderlik-\r\nGörgü Görenek-\r\nBeden Dili-\r\nMotivasyon ve Özgüven-\r\nGüzel Giyinmenin Sırları-\r\nTakım Oyunları-\r\nEtkili İletişim-\r\nKendi Everestinize Tırmanın-\r\nCilt Bakımı ve Makyaz Eğitimi',
#   'Sertifika Adı',
#   'BİLGİSAYAR MESLEK DALI EĞİTİM PROGRAMLARI KURS SERTİFİKASI',
#   'Sertifika Tarihi',
#   '07.2004',
#   'Alındığı Kurum',
#   'MED',
#   'Açıklama',
#   'Kurs içeriği:\r\nWindows\r\nWord\r\nExel\r\nPower Point\r\nAcces\r\nİnternet Erişim'],
#  ['Sertifika Adı',
#   'TOPLUM LİDERLERİ GELİYOR',
#   'Sertifika Tarihi',
#   '11.2012',
#   'Alındığı Kurum',
#   'ROTARY KULÜBÜ'],
#  ['Açıklama',
#   'KATILDIĞI SEMİNERLER VE ETKİNLİKLER : \r\nStres ve zeka Yönetimi-\r\nYeter ki inan-\r\nLiderlik-\r\nGörgü Görenek-\r\nBeden Dili-\r\nMotivasyon ve Özgüven-\r\nGüzel Giyinmenin Sırları-\r\nTakım Oyunları-\r\nEtkili İletişim-\r\nKendi Everestinize Tırmanın-\r\nCilt Bakımı ve Makyaz Eğitimi'],
#  ['Sertifika Adı',
#   'BİLGİSAYAR MESLEK DALI EĞİTİM PROGRAMLARI KURS SERTİFİKASI',
#   'Sertifika Tarihi',
#   '07.2004',
#   'Alındığı Kurum',
#   'MED'],
#  ['Açıklama',
#   'Kurs içeriği:\r\nWindows\r\nWord\r\nExel\r\nPower Point\r\nAcces\r\nİnternet Erişim'],
#  ['Seminerler ve Kurslar',
#   'Eğitim Adı',
#   'MEB onaylı elginkan vakfı 3d studio max',
#   'Eğitim Tarihi',
#   '\r\n                                                                                01.03.2012  01.04.2012\r\n                                                                                \r\n                                                                            ',
#   'Süre (Saat)',
#   '68 Saat',
#   'Eğitim Kurumu',
#   'Elignkan Vakfı',
#   'Eğitim Adı',
#   'Grafik Tasarım ve Animasyon Uygulamaları',
#   'Eğitim Tarihi',
#   '\r\n                                                                                01.05.2011  01.06.2011\r\n                                                                                \r\n                                                                            ',
#   'Süre (Saat)',
#   '90 Saat',
#   'Eğitim Kurumu',
#   'Elginkan Vakfı'],
#  ['Eğitim Adı',
#   'MEB onaylı elginkan vakfı 3d studio max',
#   'Eğitim Tarihi',
#   '\r\n                                                                                01.03.2012  01.04.2012\r\n                                                                                \r\n                                                                            ',
#   'Süre (Saat)',
#   '68 Saat',
#   'Eğitim Kurumu',
#   'Elignkan Vakfı'],
#  [],
#  ['Eğitim Adı',
#   'Grafik Tasarım ve Animasyon Uygulamaları',
#   'Eğitim Tarihi',
#   '\r\n                                                                                01.05.2011  01.06.2011\r\n                                                                                \r\n                                                                            ',
#   'Süre (Saat)',
#   '90 Saat',
#   'Eğitim Kurumu',
#   'Elginkan Vakfı'],
#  [],
#  ['Yetenekler',
#   'JavaScript Object Notation (JSON)',
#   'Resim',
#   'Ressam',
#   'Resim Yapmak',
#   'Responsive Design',
#   'Öğretmen',
#   'jQuery',
#   'HTML5',
#   'jQuery',
#   'Art Diractor',
#   'CSS / HTML',
#   'PHP (İyi)',
#   'Html, Css, Php',
#   'Apache PHP Mysql',
#   'Adobe After Effects(İleri)',
#   'Adobe Indesign (Üst Seviye)',
#   'Adobe Flash (İyi Seviye)',
#   '•\tAdobe Dreamwear(İyi Derece)',
#   '•\tAdobe Illustrator(İyi Derece)',
#   '•\tAdobe Photoshop(İyi Derece)',
#   'Mental Ray Renderer',
#   '3D Max',
#   '3D Design',
#   '3D Animation',
#   'Profesyönel Fotoğrafçılık',
#   'Grafık Tasarım',
#   'Resim Öğretmeni',
#   'Grafık Tasarım Resım',
#   'Görsel Tasarım Ve  Sanatsal Çizim Resim']]

# %%
import bs4
import requests
import re
from bs4 import BeautifulSoup

def get_competences_info(id,url):
    response = requests.get(url)
    html = response.content
    soup = BeautifulSoup(html, "html.parser")
    comp=[]
    temp=[]
    index=[0,1,6,11]
    mix_comp=[]
    competences=[]
    sobject_1 = soup.find('div', class_="resume-edit--competences-info")
    sobject_2 = sobject_1.find('div', class_="resume-edit--box")
    sobject_3 = sobject_2.find('div', class_="container")
    sobject_4 = sobject_3.find_all('div', class_="row")
    
    for tmp_obj1 in sobject_4: 
        for span in tmp_obj1.find_all('span',class_=['field-name','field-content']):
            comp.append(span.text)
        temp=comp.copy()
        comp.clear()
        mix_comp.append(temp)
    

    return mix_comp

# %%
urls=[
    'https://www.kariyer.net/ozgecmis/ahmetcan81',
    'https://www.kariyer.net/ozgecmis/alpercapkin',
    'https://www.kariyer.net/ozgecmis/ahmetyolalaner',
    'https://www.kariyer.net/ozgecmis/ahmeddemirezen',
    'https://www.kariyer.net/ozgecmis/elifffatarrr',
    'https://www.kariyer.net/ozgecmis/elifgulsu'

        
]
all_com=[]

for i in urls:
    all_com.append(get_competences_info(1,i))

# %%
print(all_com)
# Out:
# [[['\xa0', 'Bilgisayar Bilgileri', '\xa0', 'Microsoft Office adebe photoshop illüstratör indesgn freehan dreamwevaer flash php mysql java 3d studio max vray mantal ray vb. yazılımları iyi derce kullanmaktayım'], ['Sertifika Bilgileri', 'Sertifika Adı', 'TOPLUM LİDERLERİ GELİYOR', 'Sertifika Tarihi', '11.2012', 'Alındığı Kurum', 'ROTARY KULÜBÜ', 'Açıklama', 'KATILDIĞI SEMİNERLER VE ETKİNLİKLER : \r\nStres ve zeka Yönetimi-\r\nYeter ki inan-\r\nLiderlik-\r\nGörgü Görenek-\r\nBeden Dili-\r\nMotivasyon ve Özgüven-\r\nGüzel Giyinmenin Sırları-\r\nTakım Oyunları-\r\nEtkili İletişim-\r\nKendi Everestinize Tırmanın-\r\nCilt Bakımı ve Makyaz Eğitimi', 'Sertifika Adı', 'BİLGİSAYAR MESLEK DALI EĞİTİM PROGRAMLARI KURS SERTİFİKASI', 'Sertifika Tarihi', '07.2004', 'Alındığı Kurum', 'MED', 'Açıklama', 'Kurs içeriği:\r\nWindows\r\nWord\r\nExel\r\nPower Point\r\nAcces\r\nİnternet Erişim'], ['Sertifika Adı', 'TOPLUM LİDERLERİ GELİYOR', 'Sertifika Tarihi', '11.2012', 'Alındığı Kurum', 'ROTARY KULÜBÜ'], ['Açıklama', 'KATILDIĞI SEMİNERLER VE ETKİNLİKLER : \r\nStres ve zeka Yönetimi-\r\nYeter ki inan-\r\nLiderlik-\r\nGörgü Görenek-\r\nBeden Dili-\r\nMotivasyon ve Özgüven-\r\nGüzel Giyinmenin Sırları-\r\nTakım Oyunları-\r\nEtkili İletişim-\r\nKendi Everestinize Tırmanın-\r\nCilt Bakımı ve Makyaz Eğitimi'], ['Sertifika Adı', 'BİLGİSAYAR MESLEK DALI EĞİTİM PROGRAMLARI KURS SERTİFİKASI', 'Sertifika Tarihi', '07.2004', 'Alındığı Kurum', 'MED'], ['Açıklama', 'Kurs içeriği:\r\nWindows\r\nWord\r\nExel\r\nPower Point\r\nAcces\r\nİnternet Erişim'], ['Seminerler ve Kurslar', 'Eğitim Adı', 'MEB onaylı elginkan vakfı 3d studio max', 'Eğitim Tarihi', '\r\n                                                                                01.03.2012  01.04.2012\r\n                                                                                \r\n                                                                            ', 'Süre (Saat)', '68 Saat', 'Eğitim Kurumu', 'Elignkan Vakfı', 'Eğitim Adı', 'Grafik Tasarım ve Animasyon Uygulamaları', 'Eğitim Tarihi', '\r\n                                                                                01.05.2011  01.06.2011\r\n                                                                                \r\n                                                                            ', 'Süre (Saat)', '90 Saat', 'Eğitim Kurumu', 'Elginkan Vakfı'], ['Eğitim Adı', 'MEB onaylı elginkan vakfı 3d studio max', 'Eğitim Tarihi', '\r\n                                                                                01.03.2012  01.04.2012\r\n                                                                                \r\n                                                                            ', 'Süre (Saat)', '68 Saat', 'Eğitim Kurumu', 'Elignkan Vakfı'], [], ['Eğitim Adı', 'Grafik Tasarım ve Animasyon Uygulamaları', 'Eğitim Tarihi', '\r\n                                                                                01.05.2011  01.06.2011\r\n                                                                                \r\n                                                                            ', 'Süre (Saat)', '90 Saat', 'Eğitim Kurumu', 'Elginkan Vakfı'], [], ['Yetenekler', 'JavaScript Object Notation (JSON)', 'Resim', 'Ressam', 'Resim Yapmak', 'Responsive Design', 'Öğretmen', 'jQuery', 'HTML5', 'jQuery', 'Art Diractor', 'CSS / HTML', 'PHP (İyi)', 'Html, Css, Php', 'Apache PHP Mysql', 'Adobe After Effects(İleri)', 'Adobe Indesign (Üst Seviye)', 'Adobe Flash (İyi Seviye)', '•\tAdobe Dreamwear(İyi Derece)', '•\tAdobe Illustrator(İyi Derece)', '•\tAdobe Photoshop(İyi Derece)', 'Mental Ray Renderer', '3D Max', '3D Design', '3D Animation', 'Profesyönel Fotoğrafçılık', 'Grafık Tasarım', 'Resim Öğretmeni', 'Grafık Tasarım Resım', 'Görsel Tasarım Ve  Sanatsal Çizim Resim']], [['Sertifika Bilgileri', 'Sertifika Adı', 'Takdir', 'Sertifika Tarihi', '08.2018', 'Alındığı Kurum', 'Türk Silahlı Kuvvetleri', 'Açıklama', '36. Mühimmat Bölük  ...
